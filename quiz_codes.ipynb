# %%
import numpy as np
import pandas as pd

# %%
fooddata = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', error_bad_lines=False, encoding='latin-1')
fooddata.describe(include='all')
# Out:
# C:\Users\user1\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# ...

# %%
fooddata
fooddata.groupby('Unit')['Y2014', 

'Y2015', 

'Y2016', 

'Y2017', 

'Y2018'].sum()
# Out:
# C:\Users\user1\AppData\Local\Temp/ipykernel_14192/3251872488.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   fooddata.groupby('Unit')['Y2014',
#                       Y2014       Y2015       Y2016       Y2017       Y2018
# Unit
# 1000 persons     1031585.00  1058081.00  1085107.00  1112641.00  1140605.00
# 1000 tonnes      6407531.48  6449461.41  6504687.91  6737620.86  6887614.86
# g/capita/day       22062.02    22069.69    21882.46    22096.29    22092.25
# kcal/capita/day   454257.00   453383.00   451810.00   454681.00   455261.00
# kg                 49650.63    49345.13    48985.28    48690.04    49056.85

# %%
fooddata.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
fooddata.groupby('Element')['Y2014', 

'Y2015', 

'Y2016', 

'Y2017', 

'Y2018'].sum()
# Out:
# C:\Users\user1\AppData\Local\Temp/ipykernel_14192/383973415.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   fooddata.groupby('Element')['Y2014',
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# ...
